# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muhammadrohaankhan007/FlyRank-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Provisional lane: Content Refresh Prioritization
#
# I want to investigate how we can prioritize pages for content refresh by identifying pages that show signs of declining performance while still receiving meaningful search exposure. I chose this lane because the starter dataset already contains signals such as impressions, CTR, average position, content age, and update history. The goal is not simply to train a model, but to determine whether these observable signals can help create a more useful and explainable refresh-review queue for someone deciding which pages should be reviewed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Research question: Which pages should be reviewed first for a possible content refresh based on observable search and content signals?
#
# Decision: Decide which pages should receive content-review attention first when the team has limited time.
#
# Who acts: A content or SEO team would use the ranked recommendations to decide which pages to investigate.
#
# Action: The team could review the highest-priority pages first and decide whether to refresh, expand, monitor, or leave each page unchanged.
#
# Cost of a wrong call: A false positive could waste time and editorial resources on a page that did not need attention. A false negative could cause a potentially valuable page to be overlooked. The ranking should therefore support human review rather than automatically deciding that a page needs a refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains observable page-level search and content signals that are relevant to this lane. I will check the number of pages, the share currently labeled as declining, and the amount of search exposure represented by impressions. These numbers will provide an initial indication of whether there is enough observable signal to investigate refresh prioritization further.

# %%
# Clone the repository and move into it
# !git clone https://github.com/muhammadrohaankhan007/FlyRank-Internship.git
# %cd FlyRank-Internship

# Verify that the dataset exists
import os
import pandas as pd

file_path = "data/raw/content_refresh_anonymized.csv"

print("Current directory:", os.getcwd())
print("Dataset exists:", os.path.exists(file_path))

# Load the dataset
df = pd.read_csv(file_path)

# Show the 2-3 real numbers required for ML-02
print(f"Number of pages: {len(df):,}")
print(f"Declining pages: {(df['trend_direction'] == 'down').mean():.1%}")
print(f"Median 90-day impressions: {df['impressions_90d'].median():,.0f}")
# Out:
# Cloning into 'FlyRank-Internship'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 123 (delta 38), reused 97 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.84 MiB | 3.77 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/FlyRank-Internship/FlyRank-Internship
# Current directory: /content/FlyRank-Internship/FlyRank-Internship
# Dataset exists: True
# Number of pages: 30,000
# Declining pages: 54.2%
# Median 90-day impressions: 731

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What I can claim: This project can identify observed patterns in page performance and highlight pages that may deserve a content-refresh review. The results can provide directional evidence about which measurable signals are associated with declining performance and can support prioritization decisions.
#
# What I cannot claim: This project cannot prove that refreshing a page will cause its performance to improve, and it cannot claim to predict Google rankings or future search performance with certainty. The model is intended as decision-support based on the available historical data, not as causal proof or a guarantee of future results.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
